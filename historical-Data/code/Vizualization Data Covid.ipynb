# %%
# %store -r df

new_Data = df

# %%
import plotly.graph_objs as go
import plotly.express as px

# %%
fig = go.Figure()

fig.add_trace(go.Scatter(x = new_Data['date'],
                        y = new_Data['kasus_positif'],
                        mode = 'lines',
                        name = 'Indonesia',
                        marker_color = 'red'))

fig.update_layout(title = '<b> Total Confirmed Cases in Indonesia <b>',
                  title_x = 0.5,
                  title_font = dict(size = 18, color = 'Darkred'),
                  template = 'plotly_white')

fig.show()
