# %%
from dateutil.parser import parse 
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd
plt.rcParams.update({'figure.figsize': (10, 7), 'figure.dpi': 120})

# Import as Dataframe
df_Covid = pd.read_excel('DataFrame_CovidIndonesia.xlsx', parse_dates=['key_as_string'])
df_Covid.head()
# Out:
#    No             key_as_string  jumlah_meninggal  jumlah_sembuh  \
# 0   0 2020-03-02 00:00:00+00:00                 0              0
# 1   1 2020-03-03 00:00:00+00:00                 0              0
# 2   2 2020-03-04 00:00:00+00:00                 0              0
# 3   3 2020-03-05 00:00:00+00:00                 0              0
# 4   4 2020-03-06 00:00:00+00:00                 0              0
#
#    jumlah_positif  jumlah_dirawat  jumlah_positif_kum  jumlah_sembuh_kum  \
# 0               2               2                   2                  0
# 1               0               0                   2                  0
# 2               0               0                   2                  0
# 3               0               0                   2                  0
# 4               2               2                   4                  0
#
#    jumlah_meninggal_kum  jumlah_dirawat_kum
# 0                     0                   2
# 1                     0                   2
# 2                     0                   2
# 3                     0                   2
# 4                     0                   4

# %%
ser = pd.read_excel('DataFrame_CovidIndonesia.xlsx', parse_dates=['key_as_string'], index_col='key_as_string')
ser.head()
# Out:
#                            No  jumlah_meninggal  jumlah_sembuh  \
# key_as_string
# 2020-03-02 00:00:00+00:00   0                 0              0
# 2020-03-03 00:00:00+00:00   1                 0              0
# 2020-03-04 00:00:00+00:00   2                 0              0
# 2020-03-05 00:00:00+00:00   3                 0              0
# 2020-03-06 00:00:00+00:00   4                 0              0
#
#                            jumlah_positif  jumlah_dirawat  jumlah_positif_kum  \
# key_as_string
# 2020-03-02 00:00:00+00:00               2               2                   2
# 2020-03-03 00:00:00+00:00               0               0                   2
# 2020-03-04 00:00:00+00:00               0               0                   2
# 2020-03-05 00:00:00+00:00               0               0                   2
# 2020-03-06 00:00:00+00:00               2               2                   4
#
#                            jumlah_sembuh_kum  jumlah_meninggal_kum  \
# key_as_string
# 2020-03-02 00:00:00+00:00                  0                     0
# 2020-03-03 00:00:00+00:00                  0                     0
# 2020-03-04 00:00:00+00:00                  0                     0
# 2020-03-05 00:00:00+00:00                  0                     0
# 2020-03-06 00:00:00+00:00                  0                     0
#
#                            jumlah_dirawat_kum
# key_as_string
# 2020-03-02 00:00:00+00:00                   2
# 2020-03-03 00:00:00+00:00                   2
# 2020-03-04 00:00:00+00:00                   2
# 2020-03-05 00:00:00+00:00                   2
# 2020-03-06 00:00:00+00:00                   4

# %%
# Time series data source: fpp pacakge in R.
import matplotlib.pyplot as plt
df = pd.read_excel('DataFrame_CovidIndonesia.xlsx', parse_dates=['key_as_string'], index_col='key_as_string')

# Draw Plot
def plot_df(df, x, y, title="", xlabel='Date', ylabel='jumlah_sembuh', dpi=100):
    plt.figure(figsize=(16,5), dpi=dpi)
    plt.plot(x, y, color='tab:red')
    plt.gca().set(title=title, xlabel=xlabel, ylabel=ylabel)
    plt.show()

plot_df(df, x=df.index, y=df.jumlah_meninggal, title='Angka pertumbuhan kasus meninggal akibat Covid.')
